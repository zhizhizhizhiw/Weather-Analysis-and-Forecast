# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd
import time

base_url = "https://www.tianqihoubao.com/lishi/dalian/month/{year}{month:02d}.html"
headers = {
    "User-Agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/114.0.0.0 Safari/537.36"
}

all_data = []

for year in range(2022, 2025):  # 你可以自行扩大年份范围
    for month in range(1, 13):
        url = base_url.format(year=year, month=month)
        print(f"Catching: {url}")
        try:
            response = requests.get(url, headers=headers, timeout=10)
            response.encoding = "utf-8"
            soup = BeautifulSoup(response.text, "html.parser")

            table = soup.find("table", class_="weather-table")
            if table is None:
                print(f"NULL: {url}")
                continue

            rows = table.find("tbody").find_all("tr")
            for row in rows:
                cols = row.find_all("td")
                if len(cols) < 4:
                    continue
                date = cols[0].get_text(strip=True)
                weather = cols[1].get_text(strip=True)
                temp = cols[2].get_text(strip=True)
                wind = cols[3].get_text(strip=True)

                all_data.append({
                    "date": date,
                    "weather": weather,
                    "temp": temp,
                    "wind": wind,
                    "year": year,
                    "month": month
                })
            time.sleep(0.5)
        except Exception as e:
            print(f"Fail: {url}, error: {e}")
            continue

# 保存为CSV文件
df = pd.DataFrame(all_data)
df.to_csv("dalian_weather.csv", index=False, encoding="utf-8")
print("Done. Total rows:", len(df))
# Out:
# Catching: https://www.tianqihoubao.com/lishi/dalian/month/202201.html
# Fail: https://www.tianqihoubao.com/lishi/dalian/month/202201.html, error: ('Connection aborted.', ConnectionResetError(10054, '远程主机强迫关闭了一个现有的连接。', None, 10054, None))
# Catching: https://www.tianqihoubao.com/lishi/dalian/month/202202.html
# Fail: https://www.tianqihoubao.com/lishi/dalian/month/202202.html, error: ('Connection aborted.', ConnectionResetError(10054, '远程主机强迫关闭了一个现有的连接。', None, 10054, None))
# Catching: https://www.tianqihoubao.com/lishi/dalian/month/202203.html
# Fail: https://www.tianqihoubao.com/lishi/dalian/month/202203.html, error: ('Connection aborted.', ConnectionResetError(10054, '远程主机强迫关闭了一个现有的连接。', None, 10054, None))
# Catching: https://www.tianqihoubao.com/lishi/dalian/month/202204.html
# Fail: https://www.tianqihoubao.com/lishi/dalian/month/202204.html, error: ('Connection aborted.', ConnectionResetError(10054, '远程主机强迫关闭了一个现有的连接。', None, 10054, None))
# Catching: https://www.tianqihoubao.com/lishi/dalian/month/202205.html
# Fail: https://www.tianqihoubao.com/lishi/dalian/month/202205.html, error: ('Connection aborted.', ConnectionResetError(10054, '远程主机强迫关闭了一个现有的连接。', None, 10054, None))
# Catching: https://www.tianqihoubao.com/lishi/dalian/month/202206.html
# Fail: https://www.tianqihoubao.com/lishi/dalian/month/202206.html, error: ('Connection aborted.', ConnectionResetError(10054, '远程主机强迫关闭了一个现有的连接。', None, 10054, None))
# Catching: https://www.tianqihoubao.com/lishi/dalian/month/202207.html
# Fail: https://www.tianqihoubao.com/lishi/dalian/month/202207.html, error: ('Connection aborted.', ConnectionResetError(10054, '远程主机强迫关闭了一个现有的连接。', None, 10054, None))
# Catching: https://www.tianqihoubao.com/lishi/dalian/month/202208.html
# Fail: https://www.tianqihoubao.com/lishi/dalian/month/202208.html, error: ('Connection aborted.', ConnectionResetError(10054, '远程主机强迫关闭了一个现有的连接。', None, 10054, None))
# Catching: https://www.tianqihoubao.com/lishi/dalian/month/202209.html
# Fail: https://www.tianqihoubao.com/lishi/dalian/month/202209.html, error: ('Connection aborted.', ConnectionResetError(10054, '远程主机强迫关闭了一个现有的连接。', None, 10054, None))
# Catching: https://www.tianqihoubao.com/lishi/dalian/month/202210.html
# Fail: https://www.tianqihoubao.com/lishi/dalian/month/202210.html, error: ('Connection aborted.', ConnectionResetError(10054, '远程主机强迫关闭了一个现有的连接。', None, 10054, None))
# Catching: https://www.tianqihoubao.com/lishi/dalian/month/202211.html
# Fail: https://www.tianqihoubao.com/lishi/dalian/month/202211.html, error: ('Connection aborted.', ConnectionResetError(10054, '远程主机强迫关闭了一个现有的连接。', None, 10054, None))
# Catching: https://www.tianqihoubao.com/lishi/dalian/month/202212.html
# Fail: https://www.tianqihoubao.com/lishi/dalian/month/202212.html, error: ('Connection aborted.', ConnectionResetError(10054, '远程主机强迫关闭了一个现有的连接。', None, 10054, None))
# Catching: https://www.tianqihoubao.com/lishi/dalian/month/202301.html
# Fail: https://www.tianqihoubao.com/lishi/dalian/month/202301.html, error: ('Connection aborted.', ConnectionResetError(10054, '远程主机强迫关闭了一个现有的连接。', None, 10054, None))
# Catching: https://www.tianqihoubao.com/lishi/dalian/month/202302.html
# Fail: https://www.tianqihoubao.com/lishi/dalian/month/202302.html, error: ('Connection aborted.', ConnectionResetError(10054, '远程主机强迫关闭了一个现有的连接。', None, 10054, None))
# Catching: https://www.tianqihoubao.com/lishi/dalian/month/202303.html
# Fail: https://www.tianqihoubao.com/lishi/dalian/month/202303.html, error: ('Connection aborted.', ConnectionResetError(10054, '远程主机强迫关闭了一个现有的连接。', None, 10054, None))
# Catching: https://www.tianqihoubao.com/lishi/dalian/month/202304.html
# Fail: https://www.tianqihoubao.com/lishi/dalian/month/202304.html, error: ('Connection aborted.', ConnectionResetError(10054, '远程主机强迫关闭了一个现有的连接。', None, 10054, None))
# Catching: https://www.tianqihoubao.com/lishi/dalian/month/202305.html
# Fail: https://www.tianqihoubao.com/lishi/dalian/month/202305.html, error: ('Connection aborted.', ConnectionResetError(10054, '远程主机强迫关闭了一个现有的连接。', None, 10054, None))
# Catching: https://www.tianqihoubao.com/lishi/dalian/month/202306.html
# Fail: https://www.tianqihoubao.com/lishi/dalian/month/202306.html, error: ('Connection aborted.', ConnectionResetError(10054, '远程主机强迫关闭了一个现有的连接。', None, 10054, None))
# Catching: https://www.tianqihoubao.com/lishi/dalian/month/202307.html
# Fail: https://www.tianqihoubao.com/lishi/dalian/month/202307.html, error: ('Connection aborted.', ConnectionResetError(10054, '远程主机强迫关闭了一个现有的连接。', None, 10054, None))
# Catching: https://www.tianqihoubao.com/lishi/dalian/month/202308.html
# Fail: https://www.tianqihoubao.com/lishi/dalian/month/202308.html, error: ('Connection aborted.', ConnectionResetError(10054, '远程主机强迫关闭了一个现有的连接。', None, 10054, None))
# Catching: https://www.tianqihoubao.com/lishi/dalian/month/202309.html
# Fail: https://www.tianqihoubao.com/lishi/dalian/month/202309.html, error: ('Connection aborted.', ConnectionResetError(10054, '远程主机强迫关闭了一个现有的连接。', None, 10054, None))
# Catching: https://www.tianqihoubao.com/lishi/dalian/month/202310.html
# Fail: https://www.tianqihoubao.com/lishi/dalian/month/202310.html, error: ('Connection aborted.', ConnectionResetError(10054, '远程主机强迫关闭了一个现有的连接。', None, 10054, None))
# Catching: https://www.tianqihoubao.com/lishi/dalian/month/202311.html
# Fail: https://www.tianqihoubao.com/lishi/dalian/month/202311.html, error: ('Connection aborted.', ConnectionResetError(10054, '远程主机强迫关闭了一个现有的连接。', None, 10054, None))
# Catching: https://www.tianqihoubao.com/lishi/dalian/month/202312.html
# Fail: https://www.tianqihoubao.com/lishi/dalian/month/202312.html, error: ('Connection aborted.', ConnectionResetError(10054, '远程主机强迫关闭了一个现有的连接。', None, 10054, None))
# Catching: https://www.tianqihoubao.com/lishi/dalian/month/202401.html
# Fail: https://www.tianqihoubao.com/lishi/dalian/month/202401.html, error: ('Connection aborted.', ConnectionResetError(10054, '远程主机强迫关闭了一个现有的连接。', None, 10054, None))
# Catching: https://www.tianqihoubao.com/lishi/dalian/month/202402.html
# Fail: https://www.tianqihoubao.com/lishi/dalian/month/202402.html, error: ('Connection aborted.', ConnectionResetError(10054, '远程主机强迫关闭了一个现有的连接。', None, 10054, None))
# Catching: https://www.tianqihoubao.com/lishi/dalian/month/202403.html
# Fail: https://www.tianqihoubao.com/lishi/dalian/month/202403.html, error: ('Connection aborted.', ConnectionResetError(10054, '远程主机强迫关闭了一个现有的连接。', None, 10054, None))
# Catching: https://www.tianqihoubao.com/lishi/dalian/month/202404.html
# Fail: https://www.tianqihoubao.com/lishi/dalian/month/202404.html, error: ('Connection aborted.', ConnectionResetError(10054, '远程主机强迫关闭了一个现有的连接。', None, 10054, None))
# Catching: https://www.tianqihoubao.com/lishi/dalian/month/202405.html
# Fail: https://www.tianqihoubao.com/lishi/dalian/month/202405.html, error: ('Connection aborted.', ConnectionResetError(10054, '远程主机强迫关闭了一个现有的连接。', None, 10054, None))
# Catching: https://www.tianqihoubao.com/lishi/dalian/month/202406.html
# Fail: https://www.tianqihoubao.com/lishi/dalian/month/202406.html, error: ('Connection aborted.', ConnectionResetError(10054, '远程主机强迫关闭了一个现有的连接。', None, 10054, None))
# Catching: https://www.tianqihoubao.com/lishi/dalian/month/202407.html
# Fail: https://www.tianqihoubao.com/lishi/dalian/month/202407.html, error: ('Connection aborted.', ConnectionResetError(10054, '远程主机强迫关闭了一个现有的连接。', None, 10054, None))
# Catching: https://www.tianqihoubao.com/lishi/dalian/month/202408.html
# Fail: https://www.tianqihoubao.com/lishi/dalian/month/202408.html, error: ('Connection aborted.', ConnectionResetError(10054, '远程主机强迫关闭了一个现有的连接。', None, 10054, None))
# Catching: https://www.tianqihoubao.com/lishi/dalian/month/202409.html
# Fail: https://www.tianqihoubao.com/lishi/dalian/month/202409.html, error: ('Connection aborted.', ConnectionResetError(10054, '远程主机强迫关闭了一个现有的连接。', None, 10054, None))
# Catching: https://www.tianqihoubao.com/lishi/dalian/month/202410.html
# Fail: https://www.tianqihoubao.com/lishi/dalian/month/202410.html, error: ('Connection aborted.', ConnectionResetError(10054, '远程主机强迫关闭了一个现有的连接。', None, 10054, None))
# Catching: https://www.tianqihoubao.com/lishi/dalian/month/202411.html
# Fail: https://www.tianqihoubao.com/lishi/dalian/month/202411.html, error: ('Connection aborted.', ConnectionResetError(10054, '远程主机强迫关闭了一个现有的连接。', None, 10054, None))
# Catching: https://www.tianqihoubao.com/lishi/dalian/month/202412.html
# Fail: https://www.tianqihoubao.com/lishi/dalian/month/202412.html, error: ('Connection aborted.', ConnectionResetError(10054, '远程主机强迫关闭了一个现有的连接。', None, 10054, None))
# Done. Total rows: 0
